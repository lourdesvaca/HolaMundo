# %% [markdown]
# <a href="https://colab.research.google.com/github/lourdesvaca/HolaMundo/blob/Ejercicios/CSS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #CSS
# ****
#
# ### Propiedades

# %%
print('CSS')
# Out:
# CSS

# %% [markdown]
# ###Tipografias y fuentes
# **cómo visualizar - small-caps**
#
# Hace que la letra mayúscula se ve acomo minúscula con sólo modificar el tamaño.
#
# **peso - font-weight**
#
# normal -> 100-400
# bold -> 700-900
#
# **Web fonts**
#
#
# ### Texto
# **text-indent**
#
# Espaciado entre lineas
#
# **text-align**
#
# <li> center </li>
# <li> left </li>
# <li> right </li>
# <li> justify</li>
#
# **text-decoration**
# <li> underline -> subrayado </li>
# <li> overline -> raya encima </li>
# <li> live-troguth - > texto tachado </li>
# <li> none -> normal</li>
#
# **text-transform**
#
# Transformación del texto, mayus o minus
# <li> uppercase </li>
# <li> lowercase </li>
#
# ###Pseudo-clases
# Permite tener diferentes
#
# Modificar la apariencia del texto mediante css
# <li> :visited -> cuando fue visitado</li>
# <li> :active ->cuando se presiona</li>
# <li> :hover -> cuando se encuentra encima</li>
# <li> :link -> cuando es link </li>
#
# **width & height**
#
# Controla el ancho y el alto.
#
#     div {
#     width: 75%;
#     height:30px;
#     }
#
# ###Margenes y espaciado de contenido a elemento
# **margin**
#
# <li> top </li>
# <li> right </li>
# <li> bottom </li>
# <li> left </li>
#
# **padding**
#
# <li> top se repite con bottom</li>
# <li> right se repite con left</li>
#
#     h1 {
#     background: 75%;
#     padding:5px 10px;
#     }
#
# ###Bordes
# Propiedades para bordes:
# <li> border-style</li>
# <li> border-color</li>
# <li> border-top</li>
# <li> border-right</li>
# <li> border-bottom</li>
# <li> border-left</li>
#
#     h1 {
#     border-style: solid;
#     padding:5px 10px;
#     }
#
# ###Alineaciones
#
# **display**
#
# <li> inline</li>
# <li> block</li>
# <li> none</li>
#
#     div {
#     display: inline;
#     }
#
#     span {
#     display: block;
#     }
#
#     a {
#     display: none;
#     }
